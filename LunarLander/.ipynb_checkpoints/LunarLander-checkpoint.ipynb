# %%
import gym
import random
import numpy as np
from QNNAgent import QNNAgent
from matplotlib import pyplot as plt
import pylab as pl
from IPython import display
# Out:
# Using TensorFlow backend.

# %%
env = gym.make('LunarLander-v2')
agent = QNNAgent(env.observation_space.shape[0], 
                env.action_space.n)
# Out:
# /home/a-koneti/virtual-envs/tf-gpu-pip3/lib/python3.5/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
from tqdm import tqdm_notebook as tqdm
# %matplotlib inline
def one_hot(x, max_val = env.action_space.n):
    vec = [0]*max_val
    vec[x] = 1
    return vec

gamma = 0.9
epsilon = 0.2
avg_rewards = []
for trial in range(1000):
    X = []
    Y = []
    cum_rewards = []
    epsilon -= 0.001
    if epsilon < 0.05:
        epsilon = 0.05
    for i_episode in range(10):
        observation = env.reset()
        cum_reward = 0.
        for t in range(3000):
            # picking e-greedy action
#             env.render()
            action = agent.eps_greedy_action(observation, epsilon=epsilon)
            X_ = list(observation) + one_hot(action)

            #step
            observation, reward, done, info = env.step(action)

            #computing target qValue
            qVal = agent.action_value(observation, action)
            target = reward + gamma*agent.max_action_value(observation)
            cum_reward += reward
            if done:
                break
            X += [X_]
            Y += [target]
        cum_rewards += [cum_reward]
    agent.train(np.array(X),np.array(Y), epochs=2)
    display.clear_output(wait=True)
    display.display(plt.gcf())
#     print("trial %d and Avg.reward %.2f"%(trial, np.mean(cum_rewards)))
    avg_rewards += [np.mean(cum_rewards)]
    plt.title("Eps: %.2f"%epsilon)
    plt.plot(avg_rewards, 'b')
env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-e3068ab9f3f0> in <module>
#      22             # picking e-greedy action
#      23 #             env.render()
# ---> 24             action = agent.eps_greedy_action(observation, epsilon=epsilon)
#      25             X_ = list(observation) + one_hot(action)
#      26
#
# ~/Documents/Reinforcement-Learning-Algorithms/LunarLander/QNNAgent.py in eps_greedy_action(self, state, epsilon)
#      40                 rv = np.random.uniform(low=0., high=1., size=1)[0]
#      41                 if rv < (1 - epsilon):
# ---> 42                         return self.best_action(state)
#      43                 else:
#      44                         return int((rv - (1 - epsilon))/epsilon*self.action_space_dim)
#
# ~/Documents/Reinforcement-Learning-Algorithms/LunarLander/QNNAgent.py in best_action(self, state)
#      35
#      36         def best_action(self, state):
# ---> 37                 return np.argmax(self.action_values(state))
#      38
#      39         def eps_greedy_action(self, state, epsilon=0.5):
#
# ~/Documents/Reinforcement-Learning-Algorithms/LunarLander/QNNAgent.py in action_values(self, state)
#      31                 action_values = [0.]*self.action_space_dim
#      32                 for action in range(self.action_space_dim):
# ---> 33                         action_values[action] = self.action_value(state, action)
#      34                 return action_values
#      35
#
# ~/Documents/Reinforcement-Learning-Algorithms/LunarLander/QNNAgent.py in action_value(self, state, action)
#      25                 action_vec = [0]*self.action_space_dim
#      26                 action_vec[action] = 1
# ---> 27                 return self.QNN.predict([list(state) + action_vec])[0,0]
#      28
#      29         def action_values(self, state):
#
# ~/Documents/Reinforcement-Learning-Algorithms/LunarLander/QNNAgent.py in predict(self, X)
#      88
#      89         def predict(self, X):
# ---> 90                 return self.Qmodel.predict([X], verbose=2)
#
# ~/virtual-envs/tf-gpu-pip3/lib/python3.5/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# ~/virtual-envs/tf-gpu-pip3/lib/python3.5/site-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# ~/virtual-envs/tf-gpu-pip3/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2695
#    2696     def __call__(self, inputs):
# -> 2697         if hasattr(get_session(), '_make_callable_from_options'):
#    2698             if py_any(is_sparse(x) for x in self.inputs):
#    2699                 if py_any(is_tensor(x) for x in inputs):
#
# ~/virtual-envs/tf-gpu-pip3/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in get_session()
#     187         session = _SESSION
#     188     if not _MANUAL_VAR_INIT:
# --> 189         with session.graph.as_default():
#     190             variables = tf.global_variables()
#     191             candidate_vars = []
#
# /usr/lib/python3.5/contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# ~/virtual-envs/tf-gpu-pip3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in get_controller(self, default)
#    5250     try:
#    5251       with super(_DefaultGraphStack, self).get_controller(
# -> 5252           default) as g, context.graph_mode():
#    5253         yield g
#    5254     finally:
#
# ~/virtual-envs/tf-gpu-pip3/lib/python3.5/site-packages/tensorflow/python/eager/context.py in graph_mode()
#     759 def graph_mode():
#     760   """Context-manager to disable eager execution for the current thread."""
# --> 761   return context()._mode(GRAPH_MODE)  # pylint: disable=protected-access
#     762
#     763
#
# /usr/lib/python3.5/contextlib.py in helper(*args, **kwds)
#     131     @wraps(func)
#     132     def helper(*args, **kwds):
# --> 133         return _GeneratorContextManager(func, args, kwds)
#     134     return helper
#     135
#
# /usr/lib/python3.5/contextlib.py in __init__(self, func, args, kwds)
#      42         if doc is None:
#      43             doc = type(self).__doc__
# ---> 44         self.__doc__ = doc
#      45         # Unfortunately, this still doesn't provide good help output when
#      46         # inspecting the created context manager instances, since pydoc
#
# KeyboardInterrupt:

# %%
agent.QNN.Qmodel.load_weights("./eps1e14_backup.hdf5")

# %%
env = gym.wrappers.Monitor(env, './video/',video_callable=lambda episode_id: True,force = True)

# %%
cum_rewards = []
for i_episode in range(5):
    observation = env.reset()
    cum_reward = 0.
    for t in range(1000):
        # picking greedy action
        env.render()
        action = agent.best_action(observation)

        #step
        observation, reward, done, info = env.step(action)
        cum_reward += reward
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break

    cum_rewards += [cum_reward]
env.close()
print(np.mean(cum_rewards))
# Out:
# Episode finished after 575 timesteps
# Episode finished after 288 timesteps
# Episode finished after 267 timesteps
# Episode finished after 1000 timesteps
# Episode finished after 405 timesteps
# 35.38687339175054

# %%
# for i_episode in range(10):
#     observation = env.reset()
#     for t in range(1000):
#         env.render()
#         action = agent.eps_greedy_action(list(observation), epsilon=0.5)
#         observation, reward, done, info = env.step(action)
#         if done:
#             print("Episode finished after {} timesteps".format(t+1))
#             break
# env.close()
